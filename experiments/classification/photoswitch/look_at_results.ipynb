# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from fastcore.xtras import load_pickle
import pandas as pd 
import os 
from glob import glob
from pathlib import Path
from scipy.stats import sem

# %%
all_res = glob('out/*/*.pkl')

# %%
compiled_res = []

for res in all_res:
    res = load_pickle(res)


    summary = {
        'size': res['size'],
        'representation': res['representation'],
        'accuracy': res['accuracy'] if isinstance(res['accuracy'], float) else 0,
        'f1_macro': res['f1_macro'] if isinstance(res['f1_macro'], float) else 0,
        'f1_micro': res['f1_micro'] if isinstance(res['f1_micro'], float) else 0,
        'kappa': res['kappa'] if isinstance(res['kappa'], float) else 0,
        'num_epochs': res['num_epochs'],
    }
    compiled_res.append(summary)

# %%
compiled_res = pd.DataFrame(compiled_res).fillna(0)

# %%
grouped_res =compiled_res.groupby(['num_epochs', 'representation', 'size']).agg(['mean', 'sem'])

# %%
grouped_res
# Out:
#                                 accuracy            f1_macro            \
#                                     mean       sem      mean       sem
# num_epochs representation size
# 4          SMILES         10    0.000000  0.000000  0.000000  0.000000
#                           20    0.000000  0.000000  0.000000  0.000000
#                           50    0.537959  0.023979  0.450945  0.041856
#                           100   0.776000  0.023791  0.771389  0.024741
#                           200   0.828000  0.021307  0.826314  0.021498
#            name           10    0.000000  0.000000  0.000000  0.000000
#                           20    0.000000  0.000000  0.000000  0.000000
#                           50    0.568421  0.044504  0.549588  0.049768
#            selfies        10    0.000000  0.000000  0.000000  0.000000
#                           20    0.000000  0.000000  0.000000  0.000000
#                           50    0.550000  0.024698  0.480239  0.038378
# ...

# %%
grouped_res.to_pickle('photoswitch_gptj.pkl')
