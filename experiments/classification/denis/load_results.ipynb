# %%
from glob import glob
from fastcore.xtras import load_pickle
import pandas as pd

import matplotlib.pyplot as plt 
import matplotlib as mpl
import seaborn as sns

# %%
input_data = pd.read_csv('train - Dennis Svatunek.csv')

# %%
sns.distplot(input_data['Free energy of activation (kcal/mol)'])
# Out:
# /tmp/ipykernel_1291899/3145811233.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(input_data['Free energy of activation (kcal/mol)'])
# <Axes: xlabel='Free energy of activation (kcal/mol)', ylabel='Density'>

# %%
input_data['Free energy of activation (kcal/mol)'].describe()
# Out:
# count    966.000000
# mean      14.748728
# std        3.238846
# min        6.075542
# 25%       12.815930
# 50%       14.355523
# 75%       16.184398
# max       26.790242
# Name: Free energy of activation (kcal/mol), dtype: float64

# %%
input_data['Free energy of activation (kcal/mol)'].max() - input_data['Free energy of activation (kcal/mol)'].min()
# Out:
# 20.714699598992276

# %%
results =glob('out/**/*.pkl')

# %%
# Out:
# ['out/20230415_173612_/results_500_14558_5.pkl',
#  'out/20230411_201854_/results_500_14558_5.pkl',
#  'out/20230416_114212_/results_500_14560_2.pkl',
#  'out/20230416_000532_/results_700_14559_5.pkl',
#  'out/20230414_173709_/results_700_14556_2.pkl',
#  'out/20230413_021615_/results_10_14556_5.pkl',
#  'out/20230410_100122_/results_50_14558_5.pkl',
#  'out/20230412_185207_/results_700_14556_5.pkl',
#  'out/20230410_120942_/results_700_14559_2.pkl',
#  'out/20230415_020207_/results_50_14556_10.pkl',
#  'out/20230413_053735_/results_700_14557_10.pkl',
#  'out/20230416_065705_/results_50_14559_5.pkl',
#  'out/20230410_054416_/results_700_14558_5.pkl',
#  'out/20230410_165856_/results_10_14559_2.pkl',
#  'out/20230416_072929_/results_50_14559_10.pkl',
#  'out/20230413_173023_/results_500_14558_10.pkl',
#  'out/20230410_124701_/results_700_14559_5.pkl',
#  'out/20230410_083802_/results_100_14558_2.pkl',
#  'out/20230415_073852_/results_500_14557_5.pkl',
# ...

# %%
|
